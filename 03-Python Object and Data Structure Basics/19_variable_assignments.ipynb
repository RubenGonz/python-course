# %% [markdown]
# **Variables**
#
# En python las variables se pueden volver a definir
#
# En cuanto a su valor:

# %%
a = 5
a
# Out:
# 5

# %%
a = 10
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %% [markdown]
# Y se pueden usar a si mismas para obtener su nuevo valor:

# %%
a = a + a
a
# Out:
# 20

# %% [markdown]
# En cuanto a su tipo:

# %%
type(a)
# Out:
# int

# %%
a = 30.1
type(a)
# Out:
# float

# %% [markdown]
# Y asi se asignan:

# %%
my_income = 100

tax_rate = 0.1

my_taxes = my_income * tax_rate
my_taxes
# Out:
# 10.0
