# %% [markdown]
# **Strings**
#
# La importancia de las comillas en los strings

# %%
'Las comillas simples se muestran'
# Out:
# 'Las comillas simples se muestran'

# %%
"Las comillas dobles no se muestran"
# Out:
# 'Las comillas dobles no se muestran'

# %% [markdown]
# Esta sentencia falla:
#
# 'I'm going for a run'
#
# Dando el error: SyntaxError: unterminated string literal (detected at line 1)
#
# Dado que hay 3 ' y por lo tanto hay una que no esta cerrando nada, para eso podemos hacer uso de la comilla doble

# %%
"I'm going for a run"
# Out:
# "I'm going for a run"

# %% [markdown]
# Como evitar las comillas:

# %%
print("Texto sin comillas")
# Out:
# Texto sin comillas

# %% [markdown]
# Otros errores con strings:

# %%
"Texto que no sale en pantalla"
"Texto que si sale en pantalla"
# Out:
# 'Texto que si sale en pantalla'

# %% [markdown]
# Como solucionarlo:

# %%
print("Texto que no sale en pantalla")
print("Texto que si sale en pantalla")
# Out:
# Texto que no sale en pantalla
# Texto que si sale en pantalla

# %% [markdown]
# En python tambien podemos hacer uso de: \n \t entre otros:

# %%
print("Texto con \nsalto de linea")
print("---------------------------")
print("Texto con \ttabulacion")
# Out:
# Texto con
# salto de linea
# ---------------------------
# Texto con 	tabulacion

# %% [markdown]
# Y tenemos funciones como:

# %%
len("La funcion len() cuenta los caracteres de un string")
# Out:
# 51
