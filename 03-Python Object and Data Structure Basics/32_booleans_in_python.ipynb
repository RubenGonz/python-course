# %% [markdown]
# **Booleans in Python**
#
# Los booleanos sirven para establecer valores verdaderos y falsos como en otros lenguajes
#
# Un dato importanmte es que importa la capitalizacion, True es correcto pero true no

# %%
print(10 < 9)
print(5 == 5)
print(type(True))
# Out:
# False
# True
# <class 'bool'>
