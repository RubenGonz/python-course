# %% [markdown]
# **Numbers**
#
# Operadores

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
3-2
# Out:
# 1

# %% [markdown]
# Modulo or "Mod" Operator

# %%
13%2
# Out:
# 1

# %%
2**3
# Out:
# 8
